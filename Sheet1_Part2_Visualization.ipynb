# %% [markdown]
# # Part 2 - 1

# %% [markdown]
# I had to manually take the values from the other notebook because the kernel would simply crash if I had to plot these values on matplot lib for the reasons I am not sure of. <br> Nevertheless it remains a supporting notebook like the other one of the answer sheet for grade evaluation of the assignment.

# %%
# Manually taking in the loss and accuracy values of the training and the test set.
trainset_loss_SGD = [2.150539759125537,
                     1.8730332646796952,
                     1.5003468362507282,
                     1.2367172537327829,
                     1.074422391175207,
                     0.9689935427993092,
                     0.896016828350421,
                     0.8423773006462594,
                     0.8011102351044287,
                     0.7680856520051895]

trainset_loss_ADAM = [0.3739479075172054,
                     0.3320135020895172,
                     0.31491142675788925,
                     0.294973124946549,
                     0.2928844036609888,
                     0.26064458626832787,
                     0.259887996870381,
                     0.2465985964244998,
                     0.23263173327366235,
                     0.22677999032315796]

testset_loss_SGD = [0.33617898048299133,
                     0.3309130511561017,
                     0.3281965606436608,
                     0.32642786555988773,
                     0.32512844149853776,
                     0.32412721173968284,
                     0.3233428952420593,
                     0.32267403332101313,
                     0.32214005742293256,
                     0.32169404322174705]

testset_loss_ADAM = [0.37039518014640566,
                     0.3975180583015369,
                     0.3858817814831521,
                     0.4137562616805362,
                     0.39814006579909356,
                     0.40099671131865994,
                     0.4037004771411039,
                     0.4102680691203494,
                     0.42821831194458493,
                     0.45959384022814453]

trainset_accuracy_SGD = [0.5256,
                         0.5702666666666667,
                         0.6178333333333333,
                         0.6438166666666667,
                         0.659,
                         0.6744833333333333,
                         0.68725,
                         0.7005833333333333,
                         0.7133666666666667,
                         0.7264]

trainset_accuracy_ADAM = [0.9321666666666667,
                         0.9303833333333333,
                         0.9325333333333333,
                         0.9300333333333334,
                         0.9317333333333333,
                         0.9260166666666667,
                         0.9296166666666666,
                         0.9271666666666667,
                         0.9384333333333333,
                         0.9339333333333333]

testset_accuracy_SGD = [0.8892,
                         0.8909,
                         0.8918,
                         0.8923,
                         0.8934,
                         0.8932,
                         0.8934,
                         0.8937,
                         0.8942,
                         0.8945]

testset_accuracy_ADAM = [0.8843, 
                         0.8753, 
                         0.882, 
                         0.8799, 
                         0.8842, 
                         0.8852, 
                         0.8825, 
                         0.8839, 
                         0.8835, 
                         0.8796]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline


# ADAM vs SGD of the training set on the loss function 
plt.plot(trainset_loss_SGD, label="Train set on SGD")
plt.plot(trainset_loss_ADAM, label="Train set on ADAM")
plt.legend()
plt.title('ADAM VS SGD loss on a batch size of 64')
plt.ylabel('Loss')  
plt.xlabel('Epoch')  
plt.show()

# %% [markdown]
# Clearly the loss on SGD decreases to a greater extent for every epoch than for ADAM which is negligable.

# %%
# ADAM vs SGD of the test set on the loss function
plt.plot(testset_loss_SGD, label="Test set on SGD")
plt.plot(testset_loss_ADAM, label="Test set on ADAM")
plt.legend()
plt.title('ADAM VS SGD loss on a batch size of 64')
plt.ylabel('Loss')  
plt.xlabel('Epoch')  
plt.show()

# %% [markdown]
# Not sure on why the loss is increasing on the test set with the ADAM optimizer. Could also be a very different graph when run again for the same data and the optimizer.

# %%
# ADAM vs SGD of the test set on the accuracy
plt.plot(testset_accuracy_SGD, label="Test set on SGD")
plt.plot(testset_accuracy_ADAM, label="Test set on ADAM")
plt.legend()
plt.title('ADAM VS SGD accuracy on a batch size of 64')
plt.ylabel('Accuracy')  
plt.xlabel('Epoch')  
plt.show()

# %% [markdown]
# Again here there seems to be an issue with the ADAM optimizer. More epochs could make it more clear.

# %% [markdown]
# # Part 2 - 2

# %% [markdown]
# We take the values of the losses and the accuracy of each batch and we sort of plot the same for 10 epochs.

# %%
# Manually taking in the loss and accuracy values of each batch.
batch1_accuracy = [0.8773, 
                   0.88, 
                   0.8794, 
                   0.8809, 
                   0.8814, 
                   0.8809, 
                   0.8671, 
                   0.8675, 
                   0.8785, 
                   0.8769]

batch1_loss = [0.5235953990239114,
                 0.5583584936954581,
                 0.5443922763440413,
                 0.593314071179936,
                 0.5480567795513108,
                 0.5769271059051013,
                 0.5774881011142898,
                 0.7568578205737895,
                 0.5894474721939181,
                 0.6447472180620717]

batch2_accuracy = [0.8797,
                     0.8773,
                     0.8824,
                     0.8876,
                     0.8825,
                     0.8803,
                     0.8875,
                     0.8836,
                     0.8804,
                     0.8775]

batch2_loss = [0.605719848535955,
                 0.6630516795441508,
                 0.6737691823393106,
                 0.6474647032283246,
                 0.7105145682021976,
                 0.6642569295316935,
                 0.7505240259692073,
                 0.7454536410048604,
                 0.8449152358993888,
                 0.8489666421245784]

batch3_accuracy = [0.8775, 
                   0.8847, 
                   0.8874, 
                   0.8841, 
                   0.882, 
                   0.8864, 
                   0.8866, 
                   0.8858, 
                   0.8841, 
                   0.8831]

batch3_loss = [0.9529888588190079,
                 0.9761667083203792,
                 1.045451540350914,
                 1.0863357912003995,
                 1.0070372568070889,
                 1.0729454743862152,
                 0.9979065202176571,
                 1.0172511778771878,
                 1.087276618629694,
                 1.049800429046154]

# %%
# A plot of the accuracy on all the three batch sizes 
plt.plot(batch1_accuracy, label="Batch 1 (32)")
plt.plot(batch2_accuracy, label="Batch 2 (50)")
plt.plot(batch3_accuracy, label="Batch 3 (100)")
plt.legend()
plt.title('Accuracy with ADAM Optimizer for 3 different batch sizes')
plt.ylabel('Accuracy')  
plt.xlabel('Epoch')  
plt.show()

# %% [markdown]
# Here it clearly shows that higher batch sizes may not necessarily achieve higher accuracy. May be for higher epochs it becomes more clear of the result in this particular graph.

# %%
# A plot of the loss function on all the three batch sizes 
plt.plot(batch1_loss, label="Batch 1 (32)")
plt.plot(batch2_loss, label="Batch 2 (50)")
plt.plot(batch3_loss, label="Batch 3 (100)")
plt.legend()
plt.title('Loss function with Adam Optimizer for 3 different batch sizes')
plt.ylabel('Loss fn')  
plt.xlabel('Epoch')  
plt.show()

# %% [markdown]
# Evidently the loss is increasing as the batch size increases. Larger batch sizes normally traverse on bigger gradient steps when compared with the smaller batch sizes and this could be one of the reason for the increased loss. But this could also mean that we have a better gradient estimate.
